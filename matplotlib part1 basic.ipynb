# %%
import matplotlib . pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [1,2,3]
y = [2,4,6]
plt . plot(x,y)
plt . title('Our First Graph!')
plt . xlabel (' X Axis!')
plt . ylabel (' Y Axis!')
plt . show()
