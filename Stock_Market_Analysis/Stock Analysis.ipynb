# %%
import pandas_datareader.data as web
import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
start = datetime.datetime(2022,7,25)
end = datetime.datetime(2022,8,25)

# %%
tatasteel = web.DataReader("500470",'yahoo',start,end)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_datareader\yahoo\daily.py:153, in YahooDailyReader._read_one_data(self, url, params)
#     152     j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154 except KeyError:
#
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 tatasteel = web.DataReader("500470",'yahoo',start,end)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
# ...

# %%
tatasteel.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 tatasteel.head()
#
# NameError: name 'tatasteel' is not defined

# %%
google['Open'].plot(label = 'GOOGL Open price')
google['Close'].plot(label = 'GOOGL Close price')

plt.legend()
plt.show()
